# %% [markdown]
# # Hello, I am Hanna Tesfaye
# ## About Me
#
# I am a Midwifery proffessional with Masters degree in Data Analytics. I am passionate
# about using data to solve real world probelems,particularliy in health care, public health and
# business analytics.
#
# My goal is to combine domain experties in healthcare with data driven decision making
# through data analysis, visualization, and predictive analytics.
#
# # Skills
# ### Data Analytics
# -Explanatory Data Analysis (EDA)
# -Data cleaning and preprossesing
# -Data Visualization
# -Dashboard Devlopment
#
# ### Tools
# -Python
# -SQL
# -Pandas
# -Numpy
# -Matplotlib
# -Seaborn
# -Power BI
# -Excel
# -JupterNote
#
# ### Projects
# ### Maternal Health Risk Analysis risk
# Analyzed maternal health data to identify factor associated with pregnacy
# risk levels
#   **Tools:** Python, Pandas, Matplotlib
#
#
# ## Currently Learning
# -Advanced SQL
# -Machine Learning
# -Healthcare Analytics
# -Busines Intelligence
#
# ## Conntact Me
# Linkedin:[linkedin.com/in/hanna-tesfaye-30946333]
#
# GitHub:[https://github.com/HANNAGPT/HANNAGPT]
# Email[Judiye744@gmail.com]
